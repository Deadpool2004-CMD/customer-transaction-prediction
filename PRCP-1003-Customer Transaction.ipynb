# %% [markdown]
# PRCP-1003-Customer Transaction Prediction
#
# Problem Satement
#
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:-Create a predictive model which will help the bank to identify which cutomer will make tansactions in future.

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# %%
#Reading the Dataset
df=pd.read_csv('train(1).csv')

# %%
df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
df.shape
# Out:
# (695, 202)

# %%
df['target'].value_counts()
# Out:
# target
# 0    629
# 1     66
# Name: count, dtype: int64

# %%
#Checking the null value
df.isnull().sum()
# Out:
# ID_code    0
# target     0
# var_0      0
# var_1      0
# var_2      0
#           ..
# var_195    1
# var_196    1
# var_197    1
# var_198    1
# var_199    1
# Length: 202, dtype: int64

# %%
df.describe()
# Out:
#            target       var_0       var_1       var_2       var_3       var_4  \
# count  695.000000  695.000000  695.000000  695.000000  695.000000  695.000000
# mean     0.094964   10.548885   -1.659484   10.697666    6.874288   11.057293
# std      0.293376    2.968649    4.105150    2.538422    2.033124    1.661174
# min      0.000000    3.791700  -11.104400    4.027300    1.405300    6.648300
# 25%      0.000000    8.350650   -4.868300    8.725900    5.325550    9.837400
# 50%      0.000000   10.400700   -1.799000   10.654800    6.926700   11.122100
# 75%      0.000000   12.510900    1.395100   12.485200    8.404250   12.250800
# max      1.000000   19.122300    8.170100   18.108400   12.074600   15.110800
#
#             var_5       var_6       var_7       var_8  ...     var_190  \
# count  695.000000  695.000000  695.000000  695.000000  ...  694.000000
# mean    -5.042712    5.414506   16.709405    0.431023  ...    3.209098
# ...

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [ID_code, target, var_0, var_1, var_2, var_3, var_4, var_5, var_6, var_7, var_8, var_9, var_10, var_11, var_12, var_13, var_14, var_15, var_16, var_17, var_18, var_19, var_20, var_21, var_22, var_23, var_24, var_25, var_26, var_27, var_28, var_29, var_30, var_31, var_32, var_33, var_34, var_35, var_36, var_37, var_38, var_39, var_40, var_41, var_42, var_43, var_44, var_45, var_46, var_47, var_48, var_49, var_50, var_51, var_52, var_53, var_54, var_55, var_56, var_57, var_58, var_59, var_60, var_61, var_62, var_63, var_64, var_65, var_66, var_67, var_68, var_69, var_70, var_71, var_72, var_73, var_74, var_75, var_76, var_77, var_78, var_79, var_80, var_81, var_82, var_83, var_84, var_85, var_86, var_87, var_88, var_89, var_90, var_91, var_92, var_93, var_94, var_95, var_96, var_97, ...]
# Index: []
#
# [0 rows x 202 columns]

# %%
x = df.drop(['ID_code','target'], axis=1)

y=df['target']

# %%
df.target.value_counts()
# Out:
# target
# 0    629
# 1     66
# Name: count, dtype: int64

# %%
# Balancing the data
df_max=df[df.target==0]
df_min=df[df.target==1]

# %%
from sklearn.utils import resample

# %%
df_min_unsampled= resample(df_min,replace=True,n_samples=8126,random_state=123)
df_unsampled=pd.concat([df_max,df_min_unsampled])
df_unsampled.target.value_counts()
# Out:
# target
# 1    8126
# 0     629
# Name: count, dtype: int64

# %% [markdown]
# Now we got Balanced data here.

# %%
df_unsampled.dropna(inplace=True)
x=df_unsampled.iloc[:,2:]
y=df_unsampled.iloc[:,1:2]

# %% [markdown]
# # **Model Creation And Accuracy Testing**

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2,random_state=42)

# %%
Model1 = LogisticRegression()
Model1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred1=Model1.predict(x_test)

# %%
accuracy_score(y_test,pred1)
# Out:
# 0.9902912621359223

# %%
Model2=RandomForestClassifier(n_estimators=50,max_depth=8,n_jobs=-1,random_state=42)
Model2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=50, n_jobs=-1, random_state=42)

# %%
pred2=Model2.predict(x_test)

# %%
accuracy_score(y_test,pred2)
# Out:
# 0.9486007995431183

# %%
import lightgbm as lgb

# %%
Model3=lgb.LGBMClassifier(n_estimators=300,max_depth=8,n_jobs=-1,random_state=42)

# %%
Model3.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 6506, number of negative: 497
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012723 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 50900
# [LightGBM] [Info] Number of data points in the train set: 7003, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.929030 -> initscore=2.571890
# [LightGBM] [Info] Start training from score 2.571890
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
pred3=Model3.predict(x_test)

# %%
accuracy_score(y_test,pred3)
# Out:
# 1.0

# %%
print("Accuracy:",accuracy_score(y_test,pred3))
print("ROC-AUC:",roc_auc_score(y_test,pred3))
print("\nClassification Report:\n",classification_report(y_test,pred3))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,pred3))
# Out:
# Accuracy: 1.0
# ROC-AUC: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       131
#            1       1.00      1.00      1.00      1620
#
#     accuracy                           1.00      1751
#    macro avg       1.00      1.00      1.00      1751
# weighted avg       1.00      1.00      1.00      1751
#
#
# Confusion Matrix:
#  [[ 131    0]
#  [   0 1620]]

# %% [markdown]
# In this project, multiple machine learning models were developed to predict which customers will make future transactions using the anonymized PRCP-1003 dataset. After testing Logistic Regression, Random Forest, XGBoost, and LightGBM models, LightGBM achieved the highest accuracy and best overall performance. It is therefore recommended as the final model for production use to help the bank identify and target potential customers more effectively.
#
# After training and comparing multiple models — Logistic Regression, Random Forest, XGBoost, and LightGBM — the LightGBM Classifier achieved the best accuracy and performance on the test data.
#
# Hence, LightGBM is the final recommended predictive model to help the bank identify which customers are most likely to make transactions in the future. This model offers:
#
# High prediction accuracy
#
# Fast training and inference speed
#
# Strong performance on large, high-dimensional data
